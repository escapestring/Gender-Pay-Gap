# %%
#import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gpg_df1 = pd.read_csv("gpg_data.csv")

# %%
gpg_df1
# Out:
#       employee_id first_name  last_name      team_level_1  \
# 0       100650518      Pippa      North  Hospitality Team
# 1       100479104        Dan     Peters  Hospitality Team
# 2       100362807     Edward     Greene  Hospitality Team
# 3       100568527  Gabrielle    Edmunds        Sales Team
# 4       100296166    Lillian     Harris  Hospitality Team
# ...           ...        ...        ...               ...
# 1995    100439883     Nathan  Underwood  Hospitality Team
# 1996    100035325     Justin    Wallace   Investment Team
# 1997    100932674     Angela      Poole  Hospitality Team
# 1998    100419347   Jennifer      Jones        Sales Team
# 1999    100204255       Leah    Coleman  Hospitality Team
#
#              team_level_2                      job_family  \
# 0            Partnerships  Client Strategy (Job Family E)
# 1                Catering        Catering (Job  Family C)
# 2                Catering        Catering (Job  Family C)
# ...

# %%
gpg_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   employee_id                  2000 non-null   int64
#  1   first_name                   2000 non-null   object
#  2   last_name                    2000 non-null   object
#  3   team_level_1                 2000 non-null   object
#  4   team_level_2                 2000 non-null   object
#  5   job_family                   2000 non-null   object
#  6   job_family_group             2000 non-null   object
#  7   job_pay_level                2000 non-null   object
#  8   job_experience               1933 non-null   float64
#  9   race_ethnicity_(US_Only)     2000 non-null   object
#  10  gender                       2000 non-null   object
#  11  annual_salary_amount_in_usd  2000 non-null   object
#  12  hourly_or_salary             2000 non-null   object
# ...

# %%
gpg_df1.columns
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'team_level_1',
#        'team_level_2', 'job_family', 'job_family_group', 'job_pay_level',
#        'job_experience', 'race_ethnicity_(US_Only)', 'gender',
#        'annual_salary_amount_in_usd', 'hourly_or_salary', 'range_min',
#        'range_middle', 'range_max', 'full_or_part_time', 'hire_date',
#        'job_country', 'job_continent'],
#       dtype='object')

# %%
gpg_df1["annual_salary_amount_in_usd"].astype(int, copy=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rj/h7tr6zv95wlcf0_rwpshxq9m0000gn/T/ipykernel_1571/1925806323.py in <module>
# ----> 1 gpg_df1["annual_salary_amount_in_usd"].astype(int, copy=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
